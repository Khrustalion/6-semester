# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread("/Users/nikolai.khrustalev/Documents/ITMO/CV/HW1/images/three-spiderman.jpg")
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img_rgb)

# %%
img.shape
# Out:
# (436, 548, 3)

# %%
img_copy = img.copy()

img_with_1_spiderman = cv2.rectangle(img_copy, (7, 425), (220, 48), color=(0,255,0))
img_with_2_spiderman = cv2.rectangle(img_with_1_spiderman, (165, 330), (405, 5), color=(0,255,0))
img_with_3_spiderman = cv2.rectangle(img_with_2_spiderman, (285, 436), (515, 68), color=(0,255,0))

plt.imshow(cv2.cvtColor(img_with_1_spiderman, cv2.COLOR_BGR2RGB))
